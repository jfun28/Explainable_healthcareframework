# %%
import pandas as pd

# %%
df_seoul=pd.read_csv('C:\\jupyter\\Explainable Healthcare framework\\Explainable_healthcareframework\\data\\5.서울초_df_final.csv',encoding='cp949')
df_jeju=pd.read_csv('C:\\jupyter\\Explainable Healthcare framework\\Explainable_healthcareframework\\data\\5.제주초_df_final.csv',encoding='cp949')

# %%
df_seoul
# Out:
#             ID collect_datetime  gender  grade      height  weight  \
# 0      #ACGRQP       2022-07-14     2.0    4.0  136.016667    28.1
# 1      #ACGRQP       2022-07-15     2.0    4.0  136.016667    28.1
# 2      #ACGRQP       2022-07-16     2.0    4.0  136.016667    28.1
# 3      #ACGRQP       2022-07-17     2.0    4.0  136.016667    28.1
# 4      #ACGRQP       2022-07-18     2.0    4.0  136.016667    28.1
# ...        ...              ...     ...    ...         ...     ...
# 44039  #ZWOHRX       2023-01-07     2.0    6.0  156.900000    47.5
# 44040  #ZWOHRX       2023-01-08     2.0    6.0  156.900000    47.5
# 44041  #ZWOHRX       2023-01-09     2.0    6.0  156.900000    47.5
# 44042  #ZWOHRX       2023-01-10     2.0    6.0  156.900000    47.5
# 44043  #ZWOHRX       2023-01-11     2.0    6.0  156.900000    47.5
#
#        step count  burned calorie  eat calorie  sleep time
# 0           219.0       41.604375      1939.05       462.0
# 1           219.0       41.604375      1850.40       462.0
# 2           219.0       41.604375      1922.40       462.0
# 3           219.0       41.604375      1994.40       462.0
# 4           219.0       41.604375      2066.40       462.0
# ...           ...             ...          ...         ...
# 44039     20000.0       33.915000      1056.00       459.6
# 44040     20000.0       33.915000      1056.00       459.6
# 44041     20000.0       33.915000      1056.00       459.6
# 44042     20000.0       33.915000      1056.00       459.6
# 44043     20000.0       33.915000      1056.00       459.6
#
# [44044 rows x 10 columns]

# %%
df_jeju
# Out:
#            ID collect_datetime  gender  grade  height  weight  step count  \
# 0     #AGEKKL       2023-09-18       2      5   143.0    33.0       888.0
# 1     #AGEKKL       2023-09-19       2      5   143.0    33.0      7865.0
# 2     #AGEKKL       2023-09-20       2      5   143.0    33.1      9243.0
# 3     #AGEKKL       2023-09-21       2      5   143.0    33.1      7820.0
# 4     #AGEKKL       2023-09-22       2      5   143.0    33.6      4653.0
# ...       ...              ...     ...    ...     ...     ...         ...
# 4251  #ZPOZWB       2023-11-08       2      5   150.4    45.1       745.0
# 4252  #ZPOZWB       2023-11-09       2      5   150.4    45.1       837.0
# 4253  #ZPOZWB       2023-11-10       2      5   150.4    45.1       837.0
# 4254  #ZPOZWB       2023-11-11       2      5   150.4    45.1       837.0
# 4255  #ZPOZWB       2023-11-12       2      5   150.4    45.1       837.0
#
#       burned calorie  eat calorie  sleep time
# 0            64.8552      2866.05       466.0
# 1            68.9700      1158.00       379.0
# 2            18.5920      3759.00       430.0
# 3            47.4100      2358.00       474.0
# 4            47.9450      1641.00       423.0
# ...              ...          ...         ...
# 4251         58.3100      2472.00       312.0
# 4252         58.3100      2418.00       384.0
# 4253         58.3100      2418.00       384.0
# 4254         58.3100      2418.00       384.0
# 4255         58.3100      2418.00       384.0
#
# [4256 rows x 10 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming data is already loaded as df_seoul and df_jeju

# Features and labels
features = ['height', 'weight', 'step count', 'burned calorie', 'eat calorie', 'sleep time']
feature_labels = ['Height (cm)', 'Weight (kg)', 'Step Count', 'Burned Calories', 'Consumed Calories', 'Sleep Time (min)']

# Set visualization style
plt.figure(figsize=(15, 10))
plt.rcParams['font.family'] = 'Times New Roman'

# Define custom color palette
custom_palette = {'A school (Seoul)': '#1f77b4', 'B school (Jeju)': '#ff7f0e'}  # Blue for Seoul, Orange for Jeju

# Plotting
plt.figure(figsize=(18, 12))
for i, (feature, label) in enumerate(zip(features, feature_labels)):
    plt.subplot(2, 3, i + 1)
    
    # Combine data
    seoul_df = pd.DataFrame({feature: df_seoul[feature], 'region': 'A school (Seoul)'})
    jeju_df = pd.DataFrame({feature: df_jeju[feature], 'region': 'B school (Jeju)'})
    combined_df = pd.concat([seoul_df, jeju_df])
    
    # Boxplot with color palette
    sns.boxplot(x='region', y=feature, data=combined_df, palette=custom_palette)
    
    plt.title(f'{label} Comparison')
    plt.ylabel(label)
    plt.xlabel('Region')

plt.tight_layout()
plt.suptitle('Comparison of Data Features: A school (Seoul) vs B school (Jeju)', fontsize=16, y=1.02)
plt.show()
# Out:
# C:\Users\jaemin\AppData\Local\Temp\ipykernel_28144\3482326280.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='region', y=feature, data=combined_df, palette=custom_palette)
# C:\Users\jaemin\AppData\Local\Temp\ipykernel_28144\3482326280.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='region', y=feature, data=combined_df, palette=custom_palette)
# C:\Users\jaemin\AppData\Local\Temp\ipykernel_28144\3482326280.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='region', y=feature, data=combined_df, palette=custom_palette)
# C:\Users\jaemin\AppData\Local\Temp\ipykernel_28144\3482326280.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='region', y=feature, data=combined_df, palette=custom_palette)
# C:\Users\jaemin\AppData\Local\Temp\ipykernel_28144\3482326280.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='region', y=feature, data=combined_df, palette=custom_palette)
# C:\Users\jaemin\AppData\Local\Temp\ipykernel_28144\3482326280.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='region', y=feature, data=combined_df, palette=custom_palette)

# %% [markdown]
# 1. Height (cm)
# 중앙값: 제주가 서울보다 약간 높음.
#
# 분포: 두 지역 모두 비슷한 분포를 보이지만, 서울은 더 넓은 범위의 이상치를 가짐.
#
# 해석: 평균적인 신장 차이는 크지 않으며, 서울이 좀 더 다양한 키를 포함.
#
# 2. Weight (kg)
# 중앙값: 제주가 서울보다 높음.
#
# 분포: 서울은 이상치가 많고, 낮은 체중 분포가 더 많음.
#
# 해석: 제주의 체중은 전반적으로 더 높으며 서울은 저체중 비율이 많을 수 있음.
#
# 3. Step Count
# 중앙값: 제주가 서울보다 확실히 높음.
#
# 분포: 서울은 낮은 수치를 가진 분포가 많고 이상치가 더 많음.
#
# 해석: 제주의 일상 활동량(걸음 수)이 평균적으로 더 높음.
#
# 4. Burned Calories
# 중앙값: 서울이 더 높지만, 이상치가 매우 많음.
#
# 분포: 서울은 극단적으로 높은 칼로리 소모량이 많고, 제주에 비해 분산이 큼.
#
# 해석: 일부 매우 활발한 사용자가 서울에 집중되어 있거나 측정 오류 가능성 존재.
#
# 5. Consumed Calories
# 중앙값: 제주가 조금 더 높음.
#
# 분포: 두 지역 모두 이상치 존재. 서울이 더 넓은 분포.
#
# 해석: 식습관은 제주가 더 많이 섭취하는 경향이 있고 서울은 다양성이 큼.
#
# 6. Sleep Time (min)
# 중앙값: 제주가 서울보다 약간 높음.
#
# 분포: 제주가 더 고르게 분포되어 있고, 서울은 낮은 수면 시간이 많음.
#
# 해석: 제주가 평균적으로 더 많은 수면 시간을 확보.

# %%
df_seoul.describe()
# Out:
#              gender         grade        height        weight    step count  \
# count  44044.000000  44044.000000  44044.000000  44044.000000  44044.000000
# mean       1.623967      4.975207    149.917171     41.936364   3700.796982
# std        0.484394      0.822853      8.888300     10.156868   4429.144166
# min        1.000000      4.000000    121.100000     20.357143      0.000000
# 25%        1.000000      4.000000    143.500000     35.000000    479.000000
# 50%        2.000000      5.000000    150.000000     40.000000   2294.000000
# 75%        2.000000      6.000000    156.100000     47.000000   5127.912500
# max        2.000000      6.000000    175.000000     82.300000  20000.000000
#
#        burned calorie   eat calorie    sleep time
# count    44044.000000  44044.000000  44044.000000
# mean        60.372308   2386.557438    442.102288
# std        122.588824   1690.336919    100.546593
# min          0.043000    300.000000    160.000000
# 25%         41.604375   1122.000000    426.000000
# 50%         41.604375   2028.825000    462.000000
# 75%         41.604375   2825.550000    489.000000
# max       3400.000000   8000.000000    720.000000

# %%
df_jeju.describe()
# Out:
#             gender        grade       height       weight    step count  \
# count  4256.000000  4256.000000  4256.000000  4256.000000   4256.000000
# mean      1.618421     5.315789   152.773228    47.511096   5139.415006
# std       0.512205     0.464884     6.534584    10.385394   4637.008559
# min       1.000000     5.000000   141.200000    31.100000      0.000000
# 25%       1.000000     5.000000   147.100000    39.800000   1300.500000
# 50%       2.000000     5.000000   153.000000    44.900000   4019.607143
# 75%       2.000000     6.000000   157.100000    55.100000   7757.000000
# max       3.000000     6.000000   169.200000    74.200000  20000.000000
#
#        burned calorie  eat calorie   sleep time
# count     4256.000000  4256.000000  4256.000000
# mean        73.417004  2879.167716   473.994916
# std         66.712201  1858.096952    99.858895
# min          4.603000   304.227273   160.000000
# 25%         54.141063  1482.000000   438.000000
# 50%         58.310000  2488.116667   490.000000
# 75%         67.741000  3801.375000   522.000000
# max       1543.537000  8000.000000   720.000000
